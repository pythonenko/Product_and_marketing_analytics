# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-и-предобработка-данных" data-toc-modified-id="Изучение-и-предобработка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение и предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Обработка-названий-столбцов" data-toc-modified-id="Обработка-названий-столбцов-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Обработка названий столбцов</a></span></li><li><span><a href="#Обработка-типов-данных" data-toc-modified-id="Обработка-типов-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Обработка типов данных</a></span></li><li><span><a href="#Проверка-дубликатов" data-toc-modified-id="Проверка-дубликатов-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Проверка дубликатов</a></span></li><li><span><a href="#Поиск-аномалий-и-ошибок" data-toc-modified-id="Поиск-аномалий-и-ошибок-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Поиск аномалий и ошибок</a></span></li></ul></li><li><span><a href="#Рассчет-метрик" data-toc-modified-id="Рассчет-метрик-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Рассчет метрик</a></span><ul class="toc-item"><li><span><a href="#Продуктовые-метрики" data-toc-modified-id="Продуктовые-метрики-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Продуктовые метрики</a></span><ul class="toc-item"><li><span><a href="#DAU,-WAU-и-MAU" data-toc-modified-id="DAU,-WAU-и-MAU-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>DAU, WAU и MAU</a></span></li><li><span><a href="#Средняя-частота-сессий-в-день" data-toc-modified-id="Средняя-частота-сессий-в-день-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Средняя частота сессий в день</a></span></li><li><span><a href="#Время-на-сайте" data-toc-modified-id="Время-на-сайте-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Время на сайте</a></span></li><li><span><a href="#Retention-Rate" data-toc-modified-id="Retention-Rate-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>Retention Rate</a></span></li></ul></li><li><span><a href="#Метрики-электронной-коммерции" data-toc-modified-id="Метрики-электронной-коммерции-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Метрики электронной коммерции</a></span><ul class="toc-item"><li><span><a href="#Среднее-время-с-первого-посещения-сайта-до-совершения-покупки" data-toc-modified-id="Среднее-время-с-первого-посещения-сайта-до-совершения-покупки-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Среднее время с первого посещения сайта до совершения покупки</a></span></li><li><span><a href="#Среднее-количество-покупок-на-одного-покупателя" data-toc-modified-id="Среднее-количество-покупок-на-одного-покупателя-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Среднее количество покупок на одного покупателя</a></span></li><li><span><a href="#Средний-чек" data-toc-modified-id="Средний-чек-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Средний чек</a></span></li><li><span><a href="#LTV" data-toc-modified-id="LTV-2.2.4"><span class="toc-item-num">2.2.4&nbsp;&nbsp;</span>LTV</a></span></li></ul></li><li><span><a href="#Маркетинговые-метрики" data-toc-modified-id="Маркетинговые-метрики-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Маркетинговые метрики</a></span><ul class="toc-item"><li><span><a href="#Сумма-расходов-на-маркетинг" data-toc-modified-id="Сумма-расходов-на-маркетинг-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Сумма расходов на маркетинг</a></span></li><li><span><a href="#Средний-CAC-на-одного-покупателя" data-toc-modified-id="Средний-CAC-на-одного-покупателя-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Средний CAC на одного покупателя</a></span></li><li><span><a href="#ROMI-по-когортам-в-разрезе-источников" data-toc-modified-id="ROMI-по-когортам-в-разрезе-источников-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>ROMI по когортам в разрезе источников</a></span></li></ul></li></ul></li><li><span><a href="#Общие-выводы-и-рекомендации" data-toc-modified-id="Общие-выводы-и-рекомендации-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Общие выводы и рекомендации</a></span></li></ul></div>

# %% [markdown]
# # Анализ продуктовых и маркетинговых метрик Яндекс.Афиши
#
# На основе данных Яндекс.Афиши с июня 2017 года по конец мая 2018 года проанализируем, как клиенты пользуются сервисом,
# когда делают первые покупки на сайте, сколько денег приносит компании каждый клиент, а также когда расходы на привлечение клиента окупаются. Это позволит в дальнейшем оптимизировать маркетинговые расходы — отказаться от невыгодных источников трафика и перераспределить бюджет.

# %%
import pandas as pd
import numpy as np
from scipy import stats as st
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import math
import os
from IPython.display import display
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# %% [markdown]
# ## Изучение и предобработка данных

# %% [markdown]
# Откроем файлы с данными и изучим общую информацию:

# %%
def file_read (server_path, filename):
    if os.path.exists(server_path):
        file_read = pd.read_csv(server_path)
    else:
        file_read = pd.read_csv(filename)
    return file_read
    
visits = file_read('/datasets/visits_log.csv','visits_log.csv')
orders = file_read('/datasets/orders_log.csv','orders_log.csv')
costs = file_read('/datasets/costs.csv','costs.csv')

# %% [markdown]
# **Визиты**

# %%
visits.info()
display(visits.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359400 entries, 0 to 359399
# Data columns (total 5 columns):
# Device       359400 non-null object
# End Ts       359400 non-null object
# Source Id    359400 non-null int64
# Start Ts     359400 non-null object
# Uid          359400 non-null uint64
# dtypes: int64(1), object(3), uint64(1)
# memory usage: 13.7+ MB
#     Device               End Ts  Source Id             Start Ts  \
# 0    touch  2017-12-20 17:38:00          4  2017-12-20 17:20:00
# 1  desktop  2018-02-19 17:21:00          2  2018-02-19 16:53:00
# 2    touch  2017-07-01 01:54:00          5  2017-07-01 01:54:00
# 3  desktop  2018-05-20 11:23:00          9  2018-05-20 10:59:00
# 4  desktop  2017-12-27 14:06:00          3  2017-12-27 14:06:00
#
#                     Uid
# 0  16879256277535980062
# 1    104060357244891740
# 2   7459035603376831527
# 3  16174680259334210214
# 4   9969694820036681168

# %% [markdown]
# **Заказы**

# %%
orders.info()
display(orders.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50415 entries, 0 to 50414
# Data columns (total 3 columns):
# Buy Ts     50415 non-null object
# Revenue    50415 non-null float64
# Uid        50415 non-null uint64
# dtypes: float64(1), object(1), uint64(1)
# memory usage: 1.2+ MB
#                 Buy Ts  Revenue                   Uid
# 0  2017-06-01 00:10:00    17.00  10329302124590727494
# 1  2017-06-01 00:25:00     0.55  11627257723692907447
# 2  2017-06-01 00:27:00     0.37  17903680561304213844
# 3  2017-06-01 00:29:00     0.55  16109239769442553005
# 4  2017-06-01 07:58:00     0.37  14200605875248379450

# %% [markdown]
# **Расходы**

# %%
costs.info()
display(costs.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2542 entries, 0 to 2541
# Data columns (total 3 columns):
# source_id    2542 non-null int64
# dt           2542 non-null object
# costs        2542 non-null float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 59.7+ KB
#    source_id          dt  costs
# 0          1  2017-06-01  75.20
# 1          1  2017-06-02  62.25
# 2          1  2017-06-03  36.53
# 3          1  2017-06-04  55.00
# 4          1  2017-06-05  57.08

# %% [markdown]
# Необходимо обработать названия столбцов таблиц с визитами и заказами - избавиться от пробелов и перевести в нижний регистр.
# Также необходимо привести к формату datetime следующие переменные: end_ts и start_ts в таблице visits, buy_ts в таблице orders, и dt в таблице costs.
# Во всех трех таблицах пропусков не обнаружено.

# %% [markdown]
# ### Обработка названий столбцов

# %% [markdown]
# Приведем к нижему регистру названия столбцов и заменим пробелы на нижнее подчеркивание.

# %%
visits.columns = visits.columns.str.lower().str.replace(' ', '_')
orders.columns = orders.columns.str.lower().str.replace(' ', '_')
print(visits.columns)
print(orders.columns)
print(costs.columns)
# Out:
# Index(['device', 'end_ts', 'source_id', 'start_ts', 'uid'], dtype='object')
# Index(['buy_ts', 'revenue', 'uid'], dtype='object')
# Index(['source_id', 'dt', 'costs'], dtype='object')

# %% [markdown]
# ### Обработка типов данных

# %% [markdown]
# Переведем все переменные с отметкой времени к формату detetime.

# %%
visits['end_ts'] = pd.to_datetime(visits['end_ts'], format="%Y-%m-%d %H:%M:%S")
visits['start_ts'] = pd.to_datetime(visits['start_ts'], format="%Y-%m-%d %H:%M:%S")
orders['buy_ts'] = pd.to_datetime(orders['buy_ts'], format="%Y-%m-%d %H:%M:%S")
costs['dt'] = pd.to_datetime(costs['dt'], format="%Y-%m-%d")

# %% [markdown]
# ### Проверка дубликатов

# %%
print('Дубликатов в таблице visits: {}'.format(visits.duplicated().sum()))
print('Дубликатов в таблице orders: {}'.format(orders.duplicated().sum()))
print('Дубликатов в таблице costs: {}'.format(costs.duplicated().sum()))
# Out:
# Дубликатов в таблице visits: 0
# Дубликатов в таблице orders: 0
# Дубликатов в таблице costs: 0

# %% [markdown]
# Дубликатов в трех таблицах не обнаружено.

# %% [markdown]
# ### Поиск аномалий и ошибок

# %% [markdown]
# Изучим основные характеристики распределения количественных переменных и дат.

# %%
display(visits.describe(include=['datetime']))
display(orders.describe(include=['datetime']))
display(orders.describe(include=['float']))
display(costs.describe(include=['datetime']))
display(costs.describe(include=['float']))
# Out:
#                      end_ts             start_ts
# count                359400               359400
# unique               224760               224303
# top     2017-11-24 16:51:00  2017-11-24 16:06:00
# freq                     23                   19
# first   2017-06-01 00:02:00  2017-06-01 00:01:00
# last    2018-06-01 01:26:00  2018-05-31 23:59:00
#                      buy_ts
# count                 50415
# unique                45991
# top     2018-05-31 10:13:00
# freq                      9
# first   2017-06-01 00:10:00
# last    2018-06-01 00:02:00
#             revenue
# count  50415.000000
# mean       4.999647
# std       21.818359
# min        0.000000
# 25%        1.220000
# 50%        2.500000
# 75%        4.890000
# max     2633.280000
#                          dt
# count                  2542
# unique                  364
# top     2018-03-03 00:00:00
# freq                      7
# first   2017-06-01 00:00:00
# last    2018-05-31 00:00:00
#              costs
# ...

# %% [markdown]
# Данные всех трех таблиц охватывают единый временной промежуток - с 1 июня 2017 года по 1 июня 2018 года.
#
# Стоимость половины всех заказов варьируется от 1.22 до 4.89 у.е. Обнаружены нулевые значения revenue в таблице заказов. Также есть аномально большое значение 2633.28, чем объясняется смещение распределения вправо (медианное значение (2.5) существенно ниже среднего (4.99)). Нужно изучить соответствующие строки.
#
# Расходы на рекламные кампании также сильно варьируются, от практически нулевых значений до 1788 у.е. Затраты на половину реализованных кампаний составили от 21.9 до 77.3 у.е. Распределение смещено вправо. Однако наличие выбивающихся значений вполне обосновано: сервис мог проводить разовые масштабные рекламные кампании для массового привлечения трафика наряду с регулярными маркетинговыми активностями.

# %%
display(orders.query('revenue == 0').head())
print(len(orders.query('revenue == 0')))
# Out:
#                   buy_ts  revenue                   uid
# 1802 2017-06-22 18:19:00      0.0  17030528792926543083
# 2787 2017-07-07 15:54:00      0.0  10281425020415612933
# 4783 2017-08-02 14:54:00      0.0    184148767273119549
# 5095 2017-08-09 14:48:00      0.0   5603453646174104178
# 5863 2017-08-23 13:43:00      0.0   5603453646174104178
# 51

# %% [markdown]
# Обнаружен 51 заказ с нулевой выручкой. Это могут быть записи неуспешных попыток оплаты (недосточно средств, отклонение транзакции банком, ввод данных с ошибками). Удалим эти записи из данных.

# %%
orders = orders.query('revenue !=0')

# %%
print('Пользователей с заказами от 500 у.е.:', orders.query('revenue > 500')['uid'].nunique())
display(orders.query('revenue > 500'))
# Out:
# Пользователей с заказами от 500 у.е.: 3
#                    buy_ts  revenue                   uid
# 9229  2017-09-26 22:45:00   550.00  16152080406371512880
# 23165 2017-12-10 13:04:00  1195.64   5539673724080479777
# 23244 2017-12-10 20:17:00  2633.28   5539673724080479777
# 24341 2017-12-15 21:22:00   604.39   5539673724080479777
# 24607 2017-12-17 18:06:00  1109.10  11149926373378902217
# 32473 2018-02-01 19:28:00   607.44  11149926373378902217
# 36522 2018-02-23 08:54:00  1236.28  11149926373378902217
# 36682 2018-02-24 09:25:00  1221.37  11149926373378902217
# 40020 2018-03-15 19:22:00   856.78  11149926373378902217
# 40386 2018-03-18 09:13:00  1073.11  11149926373378902217
# 40643 2018-03-19 18:15:00   685.67  11149926373378902217
# 45653 2018-04-26 20:06:00   948.44  11149926373378902217
# 47507 2018-05-16 19:53:00  1080.44  11149926373378902217

# %% [markdown]
# Аномально крупные заказы совершают одни и те же пользователи. Всего три пользователя покупали на Яндекс.Афише на сумму более 500 у.е. Изучим покупки одного из них:

# %%
orders.query('uid == 11149926373378902217')
# Out:
#                    buy_ts  revenue                   uid
# 24607 2017-12-17 18:06:00  1109.10  11149926373378902217
# 24623 2017-12-17 20:00:00    97.53  11149926373378902217
# 32121 2018-01-31 19:24:00   117.33  11149926373378902217
# 32473 2018-02-01 19:28:00   607.44  11149926373378902217
# 33299 2018-02-06 21:04:00   110.98  11149926373378902217
# 36522 2018-02-23 08:54:00  1236.28  11149926373378902217
# 36682 2018-02-24 09:25:00  1221.37  11149926373378902217
# 40020 2018-03-15 19:22:00   856.78  11149926373378902217
# 40386 2018-03-18 09:13:00  1073.11  11149926373378902217
# 40643 2018-03-19 18:15:00   685.67  11149926373378902217
# 41586 2018-03-24 22:01:00   118.55  11149926373378902217
# 41774 2018-03-25 14:10:00   402.11  11149926373378902217
# 41866 2018-03-25 18:45:00   404.55  11149926373378902217
# 42151 2018-03-26 20:44:00   449.78  11149926373378902217
# 45653 2018-04-26 20:06:00   948.44  11149926373378902217
# ...

# %% [markdown]
# Все покупки выбранного пользователя существенно превышают характерные суммы заказов в выборке. Это могут быть корпоративные клиенты, приобретающие билеты в большом количестве. Такие транзакции могут смещать результаты расчетов среднего чека, LTV и ROMI и было бы корректно выделить подобных покупателей в отдельный пользовательский сегмент, для чего потребуется дополнительная информация о составе заказов. В рамках данного анализа будем рассматривать таких покупателей в составе всей совокупности.

# %% [markdown]
# ## Рассчет метрик

# %% [markdown]
# ### Продуктовые метрики

# %% [markdown]
# #### DAU, WAU и MAU

# %%
monthly_stat = visits.groupby(
    pd.Grouper(key='start_ts', freq='1M')).agg({'uid':['count', 'nunique']}).reset_index()
monthly_stat['start_ts'] = monthly_stat['start_ts'].dt.strftime('%Y-%m')
monthly_stat.columns = ['date','n_sessions', 'mau']

weekly_stat = visits.groupby(
    pd.Grouper(key='start_ts', freq='w')).agg({'uid':['count', 'nunique']}).reset_index()
weekly_stat.columns = ['date','n_sessions', 'wau']

daily_stat = visits.groupby(
    pd.Grouper(key='start_ts', freq='d')).agg({'uid':['count', 'nunique']}).reset_index()
daily_stat.columns = ['date','n_sessions', 'dau']

mau_total = monthly_stat['mau'].mean()
wau_total = weekly_stat['wau'].mean()
dau_total = daily_stat['dau'].mean()

print('Среднее значение MAU:', int(mau_total)) 
print('Среднее значение WAU:', int(wau_total)) 
print('Среднее значение DAU:', int(dau_total))

sticky_wau = dau_total/wau_total
sticky_mau = dau_total/mau_total

print('Недельная вовлеченность аудитории: {:.2%}'.format(sticky_wau))
print('Месячная вовлеченность аудитории: {:.2%}'.format(sticky_mau))
# Out:
# Среднее значение MAU: 23228
# Среднее значение WAU: 5716
# Среднее значение DAU: 905
# Недельная вовлеченность аудитории: 15.84%
# Месячная вовлеченность аудитории: 3.90%

# %%
fig = go.Figure([go.Scatter(x=monthly_stat['date'], 
                            y=monthly_stat['mau'])])
fig.update_layout(title_text='MAU', title_font_size=20,
                  xaxis_title='month',
                  yaxis_title="MAU")
fig.update_xaxes(dtick="M1", tickformat="%b\n%Y")
fig.show(width=1000, height=500, renderer='png')

# %%
fig = go.Figure([go.Scatter(x=weekly_stat['date'], 
                            y=weekly_stat['wau'])])
fig.update_layout(title_text='WAU', title_font_size=20,
                  xaxis_title='week',
                  yaxis_title="WAU")
fig.update_xaxes(dtick=86400000.0 * 14, tickformat="%W\n%b", tickangle = 0)
fig.show(width=1000, height=500, renderer='png')

# %%
fig = go.Figure([go.Scatter(x=daily_stat['date'], 
                            y=daily_stat['dau'])])
fig.update_layout(title_text='DAU', title_font_size=20,
                  xaxis_title='day',
                  yaxis_title="DAU")
fig.update_xaxes(dtick=86400000.0 * 7, tickformat="%d-%b", tickangle = 270)
fig.show(width=1000, height=500, renderer='png')

# %% [markdown]
# **Вывод.** Анализ пользовательской активности показал, что в среднем к сервису Яндекс.Афиша обращаются 23228 уникальных пользователей в месяц, 5716 уникальных пользователей в неделю и 905 уникальных пользователей в день.
#
# Пиковая пользовательская активность наблюдалась в ноябре, в 47 неделю, рекордная посещаемость зафиксирована 24 ноября (3319).
# Минимальная активность наблюдалась в августе, в 31 неделю. Антирекорд по дневной посещаемости установлен 31 марта и 1 апреля - вероятно, у сервиса был технический сбой в эти дни.
#
# Значения показателей sticky factor говорят о низкой вовлеченности аудитории: всего 15.8% для недельной аудитории и 3.9% - для месячной. Эти показатели говорят о том, что каждый день аудитория сервиса почти полностью обновляется (если сравнивать с 1/30 и 1/7 соответственно).

# %% [markdown]
# #### Средняя частота сессий в день

# %% [markdown]
# Определим, сколько раз за день пользователи в среднем заходят на сайт.

# %%
daily_stat['sessions_per_user'] = (daily_stat['n_sessions']/daily_stat['dau']).round(2)
print('Среднее количество сессий на пользователя в день:', daily_stat['sessions_per_user'].mean().round(2))
# Out:
# Среднее количество сессий на пользователя в день: 1.08

# %%
sessions_per_day = daily_stat.groupby(
    pd.Grouper(key='date', freq='m')).agg({'sessions_per_user':'mean'}).round(3).reset_index()
sessions_per_day['date'] = sessions_per_day['date'].dt.strftime('%Y-%m')

# %%
fig = go.Figure([go.Scatter(x=sessions_per_day['date'], 
                            y=sessions_per_day['sessions_per_user'])])
fig.update_layout(title_text='Sessions per user', title_font_size=20,
                  xaxis_title='month',
                  yaxis_title="sessions per user")
fig.update_xaxes(dtick="M1", tickformat="%b\n%Y")
fig.show(width=1000, height=500, renderer='png')

# %% [markdown]
# **Вывод.** В среднем пользователи совершают 1,08 визитов в день. Метрика незначительно увеличивалась в ноябре, а также в декабре и феврале. Минимальное значение метрики наблюдалось в августе.

# %% [markdown]
# #### Время на сайте

# %% [markdown]
# Исследуем продолжительность типичной пользовательской сессии за весь период. Чтобы выбрать подходящую среднюю меру, построим график распределения.

# %%
visits['session_duration_sec'] = (visits['end_ts'] - visits['start_ts']).dt.seconds

visits.plot(y = 'session_duration_sec', kind = 'hist', bins = 100, color = 'peru',
            legend=None, grid=True, figsize = (10,4), range = (0,10000))
plt.xlabel('Продолжительность сессии, секунд')
plt.ylabel('Частота')
plt.title('Продолжительность сессий')
plt.show()

display(visits['session_duration_sec'].describe())
# Out:
# count    359400.000000
# mean        643.506489
# std        1016.334786
# min           0.000000
# 25%         120.000000
# 50%         300.000000
# 75%         840.000000
# max       84480.000000
# Name: session_duration_sec, dtype: float64

# %% [markdown]
# Распределение продолжительности пользовательских сессий сильно отличается от нормального: из-за присутствия выбросов наблюдается явное смещение вправо, а среднее значение больше медианы почти в два раза. Кроме того, в базе есть записи с нулевой продолжительностью сессий. Поэтому в качестве средней меры ASL вместо среднего или медианы будем использовать моду.

# %%
asl = (visits.query('session_duration_sec > 0')['session_duration_sec']).mode()
print('Средняя продолжительность сессии составляет {} секунд.'.format(asl[0]))
# Out:
# Средняя продолжительность сессии составляет 60 секунд.

# %% [markdown]
# **Вывод.** В среднем сессия пользователя длится 1 минуту. Учитывая специфику сервиса Яндекс.Афиша, 60 секунд - недосточно для желаемого customer journey, состоящего из поиска, выбора билетов и оформления заказа, следовательно, уже на данном этапе можно предположить, что большая часть пользователей покидает сайт, не оформив заказ. Чтобы это выяснить, изучим метрики электронной коммерции, в частности, мтерику времени от первого визита до покупки.

# %% [markdown]
# #### Retention Rate

# %% [markdown]
# Применяя когортный анализ, рассчитаем Retention Rate и изобразим изменения метрики во времени на графике.

# %%
visits['visit_month'] = visits['start_ts'].astype('datetime64[M]')

first_activity_month = visits.groupby(['uid'])['visit_month'].min()
first_activity_month.name = 'first_visit_month'

visits = visits.join(first_activity_month, on='uid')

visits['cohort_lifetime'] = (visits['visit_month'] - visits['first_visit_month'])/ np.timedelta64(1, 'M')
visits['cohort_lifetime'] = visits['cohort_lifetime'].round().astype('int')

cohorts = visits.groupby(['first_visit_month','cohort_lifetime']).agg({'uid':'nunique'}).reset_index() 

initial_users_count = cohorts[cohorts['cohort_lifetime'] == 0][['first_visit_month', 'uid']]
initial_users_count = initial_users_count.rename(columns={'uid':'cohort_users'}) 
cohorts = cohorts.merge(initial_users_count,on='first_visit_month') 
cohorts['retention'] = (cohorts['uid']/cohorts['cohort_users']).round(4)

retention_pivot = cohorts.pivot_table(
    index='first_visit_month',
    columns='cohort_lifetime',
    values='retention',
    aggfunc='sum',
)
retention_pivot.index = retention_pivot.index.strftime('%Y-%m')

sns.set(style='white')
plt.figure(figsize=(13, 9))
plt.title('Cohorts: User Retention')
sns.heatmap(retention_pivot, annot=True, fmt='.1%', 
            vmin=0, vmax=0.1)
plt.show()

# %% [markdown]
# Найдем средний Retention Rate на второй месяц «жизни» когорт.

# %%
print("Retention Rate на второй месяц «жизни» когорт: {0:.2f}%".format(retention_pivot[1].mean()*100))
# Out:
# Retention Rate на второй месяц «жизни» когорт: 6.52%

# %% [markdown]
# **Вывод.**
# Средний Retention Rate второго месяца составил 6.52%. Наблюдается заметная негативная динамика RR второго месяца. Так, когорты, привлеченные с августа по ноябрь, удерживали на 2 месяц не менее 7.7%, в то время как RR декабрьской и последующих когорт не превышал 6% и постепенно снижался.

# %% [markdown]
# ### Метрики электронной коммерции

# %% [markdown]
# #### Среднее время с первого посещения сайта до совершения покупки

# %% [markdown]
# Исследуем, сколько времени в среднем проходит с момента первого посещения сайта до совершения покупки.

# %%
first_visit_date = visits.groupby(['uid'])['start_ts'].min()
first_visit_date.name = 'first_visit_datetime'

visits = visits.join(first_visit_date, on='uid')

first_purchase = orders.groupby('uid')['buy_ts'].min().to_frame()
first_purchase.columns = ['first_purchase_datetime']
first_purchase = pd.merge(first_purchase, first_visit_date, left_index=True, right_index=True, how='left')
first_purchase['time_to_buy']= \
(first_purchase['first_purchase_datetime']-first_purchase['first_visit_datetime']).dt.seconds//60

display(first_purchase['time_to_buy'].describe().round())

first_purchase['time_to_buy'].plot(kind = 'hist', bins = 50, color = 'peru',
            legend=None, grid=True, figsize = (10,4), range = (0,250))
plt.xlabel('Время, минут')
plt.ylabel('Частота')
plt.title('Время до первой покупки')
plt.show()
# Out:
# count    36509.0
# mean       249.0
# std        430.0
# min          0.0
# 25%          4.0
# 50%         16.0
# 75%        252.0
# max       1439.0
# Name: time_to_buy, dtype: float64

# %%
time_to_buy = first_purchase['time_to_buy'].round(3).mode()
print('Модальное значание времени до покупки составляет {} минуту.'.format(time_to_buy[0]))
# Out:
# Модальное значание времени до покупки составляет 1 минуту.

# %% [markdown]
# **Вывод.**
# В среднем с момента первого посещенияя до первой покупки проходит 249 минут, половина заказов совершается за временной промежуток от 4 до 252 минут, однако распределение метрики скошено вправо, а среднее значение превышает медиану в 15 раз. Поэтому также следует учитывать, что мода метрики равна 1 минуте.

# %% [markdown]
# #### Среднее количество покупок на одного покупателя
# Рассчитаем среднее количество покупателей и совершенных ими покупок для когорт в разрезе месяцев.

# %%
first_purchase_dates = orders.groupby('uid')['buy_ts'].min()
first_purchase_dates.name = 'first_purchase_datetime'
orders = orders.join(first_purchase_dates, on='uid')

orders['purchase_month'] = orders['buy_ts'].astype('datetime64[M]')
orders['first_purchase_month'] = orders['first_purchase_datetime'].astype('datetime64[M]')

purchases_grouped_by_cohorts = orders.groupby(
    ['first_purchase_month', 'purchase_month']
)['uid'].agg(['count', 'nunique']).reset_index()

purchases_grouped_by_cohorts['cohort_lifetime'] = (
    purchases_grouped_by_cohorts['purchase_month']
    - purchases_grouped_by_cohorts['first_purchase_month'])

purchases_grouped_by_cohorts['cohort_lifetime'] = purchases_grouped_by_cohorts[
    'cohort_lifetime'] / np.timedelta64(1, 'M')
purchases_grouped_by_cohorts['cohort_lifetime'] = (
    purchases_grouped_by_cohorts['cohort_lifetime'].round().astype('int'))

# %% [markdown]
# Применяя когортный анализ, рассчитаем количество покупок за 6 месяцев.

# %%
six_month_cohorts = purchases_grouped_by_cohorts[(
    purchases_grouped_by_cohorts['first_purchase_month'] < '2018-01-01')& (
    purchases_grouped_by_cohorts['cohort_lifetime'] < 6)]

lifetime_pivot = six_month_cohorts.pivot_table(
    index='first_purchase_month', columns='cohort_lifetime', values='count',aggfunc='sum')

lifetime_pivot.index = lifetime_pivot.index.strftime('%y-%m')

sns.set(style='white')
plt.figure(figsize=(10, 7))
plt.title('Cohorts: Orders')
sns.heatmap(lifetime_pivot, annot=True, fmt='1', vmax=500, 
            vmin=100, center= 300, cmap= 'coolwarm')
plt.show()

# %% [markdown]
# С сентября 2017 года число покупок в первый, второй и третий месяцы росло. У большинства когорт число покупок заметно снижается на 5 и 6 месяцы.
#
# Рассчитаем среднее количество покупок на одного пользователя за 6 месяцев.

# %%
lifetime_pivot['sum'] = lifetime_pivot.sum(axis=1)

n_users = six_month_cohorts[six_month_cohorts['cohort_lifetime'] == 0].pivot_table(
    index='first_purchase_month', values=['nunique'], aggfunc='sum')
n_users.index = n_users.index.strftime('%y-%m')

lifetime_pivot = lifetime_pivot.merge(n_users,left_index=True, right_index=True)
lifetime_pivot['purchases_per_users'] = (lifetime_pivot['sum']/lifetime_pivot['nunique']).round(2)

# %%
display(lifetime_pivot[['sum', 'nunique','purchases_per_users']])
print('Покупок на пользователя в среднем за 6 месяцев:', lifetime_pivot['purchases_per_users'].mean().round(2))
# Out:
#         sum  nunique  purchases_per_users
# 17-06  3434     2022                 1.70
# 17-07  2663     1922                 1.39
# 17-08  1968     1369                 1.44
# 17-09  3649     2579                 1.41
# 17-10  5794     4340                 1.34
# 17-11  5776     4078                 1.42
# 17-12  5890     4380                 1.34
# Покупок на пользователя в среднем за 6 месяцев: 1.43

# %% [markdown]
# В среднем пользователи Яндекс.Афиша совершают 1.43 покупок за полгода. Показатель снижается с каждой новой когортой, что может говорить о более низкой вовлеченности новых пользователей сервиса.

# %% [markdown]
# #### Средний чек

# %% [markdown]
# Рассчитаем средний чек, применяя группировку по времени совершения покупки, и отразим результаты на графике.

# %%
print('Средний чек равен', orders['revenue'].mean().round(2))

avg_check = orders.groupby('purchase_month')['revenue'].agg('mean').round(2).reset_index()

fig = go.Figure([go.Scatter(x=avg_check['purchase_month'], 
                            y=avg_check['revenue'])])
fig.update_layout(title_text='Average check', title_font_size=20,
                  xaxis_title='month',
                  yaxis_title="Average check")
fig.update_xaxes(dtick="M1", tickformat="%b\n%Y")
fig.show(width=1000, height=500, renderer='png')
# Out:
# Средний чек равен 5.0

# %% [markdown]
# Средний чек за весь анализируемый период составляет 5 у.е., при этом максимальное значение (5.86) было достигнуто в декабре 2017 года, а минимальное (3.42) - в июне 2018 года. Однако следует учитывать чувствительность данной метрики к выбросам и возможное влияние редких крупных покупок на показатели отдельных месяцев, обнаруженных ранее.

# %% [markdown]
# #### LTV

# %% [markdown]
# Рассчитаем средний LTV по когортам за 6 месяцев.

# %%
cohort_sizes = (
    orders.groupby('first_purchase_month')
    .agg({'uid': 'nunique'})
    .reset_index()
)
cohort_sizes.columns = ['first_purchase_month', 'n_buyers']

margin_rate = 1

cohorts = (
    orders.groupby(['first_purchase_month', 'purchase_month'])
    .agg({'revenue': 'sum'})
    .reset_index()
)
report = pd.merge(cohort_sizes, cohorts, on='first_purchase_month')
report['gp'] =  report['revenue'] * margin_rate
report['age'] = (report['purchase_month'] - report['first_purchase_month']) / np.timedelta64(1, 'M')
report['age'] = report['age'].round().astype('int') 
report['ltv'] = report['gp'] / report['n_buyers']

six_month_report = report[(report['first_purchase_month'] < '2018-01-01')& (report['age'] < 6)]

result = six_month_report.pivot_table(
    index='first_purchase_month', columns='age', values='ltv', aggfunc='mean'
).round(2)

result = result.cumsum(axis=1).round(2)

result.index = result.index.strftime('%Y-%m')

# %% [markdown]
# Отразим на графике изменения метрики LTV во времени по когортам.

# %%
sns.set(style='white')
plt.figure(figsize=(9, 7))
plt.title('Cohorts: LTV')
sns.heatmap(result, annot=True, fmt='.2g', 
            vmin=4, vmax=12, cmap= 'coolwarm')
plt.show()

# %% [markdown]
# С точки зрения накопленного за 6 месяцев LTV сентябрьская, и в меньшей степени июньская, когорты являются наиболее ценными для бизнеса. В ноябре и октябре были привлечены пользователи с наименьшим потенциалом LTV.

# %% [markdown]
# ### Маркетинговые метрики

# %% [markdown]
# #### Сумма расходов на маркетинг

# %% [markdown]
# Посчитаем общую сумму расходов на маркетинг.

# %%
print('Общая сумма расходов на маркетинг:', costs['costs'].sum())
# Out:
# Общая сумма расходов на маркетинг: 329131.62

# %% [markdown]
# Общая сумма расходов на маркетинг  за год составила 329131 у.е. Выясним, как траты распределены по источникам.

# %%
sources = costs.pivot_table(index='source_id', values=['costs'], aggfunc=['sum']).reset_index()
sources.columns = ['source_id', 'costs']
display(sources)

pie, ax = plt.subplots(figsize=[10,9])
labels = sources['source_id']
plt.pie(x=sources['costs'], autopct="%.1f%%", labels=labels, colors=plt.cm.Set3.colors, pctdistance=0.9)
plt.title('Затраты по источникам', fontsize=14)
plt.show()
# Out:
#    source_id      costs
# 0          1   20833.27
# 1          2   42806.04
# 2          3  141321.63
# 3          4   61073.60
# 4          5   51757.10
# 5          9    5517.49
# 6         10    5822.49

# %% [markdown]
# Источник 3 составляет почти половину совокупных расходов на маркетинг, также существенную долю занимают 4 и 5 источники.
#
# Визуализируем изменения метрик во времени.

# %%
monthly_costs = costs.groupby([
    'source_id', pd.Grouper(key='dt', freq='M')]).agg({'costs': 'sum'}).reset_index()
weekly_costs = costs.groupby([
    'source_id', pd.Grouper(key='dt', freq='w')]).agg({'costs': 'sum'}).reset_index()
daily_costs = costs.groupby([
    'source_id', pd.Grouper(key='dt', freq='d')]).agg({'costs': 'sum'}).reset_index()

# %%
plt.figure(figsize=(14,7))
sns.set_style('darkgrid')
sns.set_palette('Set2')
sns.lineplot(data=monthly_costs, x="dt", y="costs", hue="source_id", legend="full", palette="tab10")
plt.xlabel("month")
plt.ylabel("costs")
plt.title('Marketing costs', fontsize=14)
plt.show()

# %% [markdown]
# **Вывод.** Пик маркетинговой активности пришелся на период с ноября 2017 года по январь 2018 года. 3 источник доминировал в затратах на маркетинг на протяжении всего анализируемого периода. В декабре маркетинговые затраты были максимальными почти по всем источникам, кроме 4. В сентябре, наоборот, произошло сокращение расходов по всем источникам.

# %% [markdown]
# #### Средний CAC на одного покупателя

# %% [markdown]
# Рассчитаем средний CAC на одного покупателя для всего проекта.

# %%
CAC = (costs['costs'].sum())/(orders['uid'].nunique())
print('Средний CAC проекта равен', CAC.round(2))
# Out:
# Средний CAC проекта равен 9.02

# %% [markdown]
# Привлечение одного покупателя в среднем обошлось компании в 9.02 у.е.
# Рассчитаем средний CAC по когоратам и отобразим результат на графике.

# %%
costs['month'] = costs['dt'].astype('datetime64[M]')
report = pd.merge(
    report, costs.groupby('month').sum(), left_on='first_purchase_month', right_on='month'
)
report['cac'] = report['costs'] / report['n_buyers']

output = report.pivot_table(
    index='first_purchase_month', values='cac', aggfunc='mean').reset_index()

fig = go.Figure([go.Scatter(x=output['first_purchase_month'], 
                            y=output['cac'])])
fig.update_layout(title_text='CAC', title_font_size=20,
                  xaxis_title='month',
                  yaxis_title="CAC")
fig.update_xaxes(dtick="M1", tickformat="%b\n%Y")
fig.show(width=1000, height=500, renderer='png')

# %% [markdown]
# Наименее эффективными оказались маркетинговые кампании в августе, когда привлечение каждого пользователя стоило 10.8 у.е. Минимальный CAC был достигнут в мае и составил 7.4 у.е.

# %% [markdown]
# Рассчитаем средний CAC для каждого источника трафика. Для этого сопоставим покупателей и источники их привлечения по ближайшей отметке времени в таблице visits.

# %%
orders_sorted = orders.sort_values(by='buy_ts')
visits_sorted = visits.sort_values(by='start_ts')

merge = pd.merge_asof(
    orders_sorted, visits_sorted, left_on='buy_ts', right_on='start_ts', by='uid', direction="backward")

sources = merge.groupby(['source_id']).agg({'uid': 'nunique'}).reset_index()

sources_report = pd.merge(
    sources, costs.groupby(['source_id']).sum(), on='source_id'
)
sources_report['cac'] = sources_report['costs'] / sources_report['uid']
sources_report.columns = ['source_id', 'n_buyers', 'costs', 'cac']

plt.figure(figsize=(15,4))
sns.barplot(x = sources_report['source_id'], y=sources_report['cac'], palette='YlOrRd')
plt.title("Средний CAC по источникам трафика")
plt.xlabel("Источник")
plt.ylabel("CAC")
plt.show()

# %% [markdown]
# Источник 3 не только самый затратный, но и самый неэффективный: привлечение одного клиента через этот источник обходится более чем в 14 у.е. Наиболее эффективными оказались 1, 9 и 10 источники, CAC которых не превышает 5 у.е.

# %%
month_sources = merge.groupby(['source_id', 'visit_month']).agg({'uid': 'nunique'}).reset_index()
month_sources['month'] = month_sources['visit_month'].astype('datetime64[M]')
monthly_costs['month'] = monthly_costs['dt'].astype('datetime64[M]')

sources_month_report = pd.merge(month_sources, monthly_costs, on=['source_id', 'month']).reset_index()
sources_month_report['cac'] = sources_month_report['costs'] / sources_month_report['uid']

plt.figure(figsize=(14,7))
sns.set_style('darkgrid')
sns.set_palette('Set2')
sns.lineplot(
    data=sources_month_report, x="month", y="cac", 
    hue="source_id", legend="full", palette="tab10")
plt.xlabel("month")
plt.ylabel("CAC")
plt.title('CАС', fontsize=14)
plt.show()

# %% [markdown]
# 3 источник самый неэффективный с точки знения CAC на протяжении всего времени, в то время как первый - самый эффективный.

# %% [markdown]
# #### ROMI по когортам в разрезе источников

# %% [markdown]
# Рассчитаем ROMI по когортам.

# %%
report['romi'] = report['ltv']/report['cac'] 
report

romi_pivot = report.pivot_table(
    index='first_purchase_month',
    columns='age',
    values='romi',
    aggfunc='sum',
)
romi_pivot.index = romi_pivot.index.strftime('%Y-%m')
romi_pivot = romi_pivot.cumsum(axis=1).round(2) 

sns.set(style='white')
plt.figure(figsize=(13, 9))
plt.title('Cohorts: ROMI')
sns.heatmap(romi_pivot, annot=True, fmt='.2g', 
            vmin=0.4, vmax=1.2, center = 1, cmap= 'coolwarm')
plt.show()

# %% [markdown]
# Сентябрьская когорта достигла окупаемости маркетинговых вложений раньше других когорт - на 4 месяц. Также на окупаемость вышла когорта июня - на 7 месяц после привлечения. Остальные когорты на достигли точки возврата расходов на маркетинг. В целом можно говорить о снижении эффективности рекламных кампаний с каждой новой когортой, однако в мае ситуация улучшилась.

# %%
sources_cohort_sizes = (
    merge.groupby(['first_purchase_month', 'source_id'])
    .agg({'uid': 'nunique'})
    .reset_index())

sources_cohort_sizes.columns = ['first_purchase_month', 'source_id', 'n_buyers']

sources_cohorts = (
    merge.groupby(['source_id','first_purchase_month', 'purchase_month'])
    .agg({'revenue': 'sum'})
    .reset_index()
)

sources_report = pd.merge(sources_cohort_sizes, sources_cohorts, on=['source_id','first_purchase_month'])

sources_report['gp'] =  sources_report['revenue'] * margin_rate
sources_report['age'] = (sources_report['purchase_month'] - sources_report['first_purchase_month']) / np.timedelta64(1, 'M')
sources_report['age'] = sources_report['age'].round().astype('int') 
sources_report['ltv'] = sources_report['gp'] / sources_report['n_buyers']
costs_report = costs.groupby(['month','source_id']).sum()
sources_report = pd.merge(
    sources_report, costs_report, left_on=['first_purchase_month','source_id'], right_on=['month','source_id']
)
sources_report['cac'] = sources_report['costs'] / sources_report['n_buyers']
sources_report['romi'] = sources_report['ltv'] / sources_report['cac']

# %%
sources_output = (sources_report.pivot_table(
    index=['source_id','first_purchase_month'], columns='age', values='romi', aggfunc='mean'
))
sources_output.iloc[:, 0:12] = sources_output.iloc[:, 0:12].cumsum(axis=1).round(2) 

sources_output = sources_output.reset_index()

# %%
sources = [ 1,  2,  3,  4,  5,  9, 10]
y_axis_labels = ['17-06', '17-07', '17-08', '17-09', '17-10', '17-11',
       '17-12', '18-01', '18-02', '18-03', '18-04', '18-05']

a = 3  # number of rows
b = 3  # number of columns
c = 1  # initialize plot counter

fig = plt.figure(figsize=(15,20))

for i in sources:
    plt.subplot(a, b, c)
    plt.title('Source: {}'.format(i))
    plt.xlabel(i)
    x = sources_output[sources_output['source_id'] == i].iloc[:, 3:14]
    sns.heatmap(x, annot=True, fmt='.1g', vmin=0, vmax=4, 
                center = 1, cmap= 'coolwarm', annot_kws={"fontsize":8},
                yticklabels=y_axis_labels, cbar=False)
    c = c + 1

plt.show()

# %% [markdown]
# **Вывод.** Первый источник оказался наиболее эффективным, поскольку привлеченный через него трафик окупался с первого месяца среди всех когорт, однако его эффективность снижалась в декабре 2017 года - феврале 2018 года. Источник 3, напротив, не окупился на всем протяжении жизни каждой из когорт. 10 источник окупился лишь для мартовской когорты, а 4 - только для ноябрьской. 2,5 и 9 источники окупились только для части когорт, зачастую со второго месяца. Изучение дополнительных параметоров рекламных кампаний по этим источникам позволило бы определить факторы, благодаря которым для одних когорт источник окупился раньше, чем для других.

# %% [markdown]
# ## Общие выводы и рекомендации
#
# Проведенный анализ коммерческих, маркетинговых и продуктовых метрик сервиса Яндекс.Афиша позволил выяснить, что:
#
# * В среднем к сервису обращаются 23228 уникальных пользователей в месяц, 5716 уникальных пользователей в неделю и 905 уникальных пользователей в день. Пиковая посещаемость сервиса пришлась на ноябрь, минимальная - на август.
# * Продуктовой команде важно учитывать, что ежедневно аудитория сервиса почти полностью обновляется, о чем свидетельствуют значения sticky factor: всего 15.8% для недельной аудитории и 3.9% - для месячной. При развитии продукта следует ориентироваться на механизмы повышения удержания и вовлеченности аудитории, а в новых маркетинговых кампаниях работать над повышением качества трафика. Также команде продукта рекомендуется выяснить причины нулевого трафика 1 апреля.
# * В среднем пользователи совершают 1,08 визитов в день, при этом средняя сессия пользователя длится 1 минуту.
# * В среднем с момента первого посещения сайта Яндекс.Афиши до первой покупки проходит 249 минут, при этом половина заказов совершается за временной промежуток от 4 до 252 минут, а мода значения равна 1 минуте. Для выяснения возможных причин длинного правого хвоста распределения следует дополнительно изучить метрики конверсии для отдельных этапов воронки электронной коммерции и выявить проблемные этапы.
# * Пользователи Яндекс.Афиша совершают 1.43 покупок за полгода в среднем, однако показатель снижается с каждой новой когортой.
# * Средний чек составляет 5 у.е. и варьируется для разных месяцев от 3.42 до 5.86. Явной положительной или отрицательной динамики не выявлено. Однако были обнаружены клиенты, покупки которых существенно превышают характерные суммы заказов в выборке (предположительно, корпоративные заказчики). Поэтому для получения менее смещенных оценок среднего чека рекомендуется разделить покупателей на сегменты на основе информации о составе заказов.
# * Только 6.5% привлеченных покупателей совершают заказы на второй месяц в среднем, однако несколько когорт (июньская, сентябрьская и ноябрьская) показали нулевой Retention Rate второго месяца. С течением времени Retention Rate каждой когорты может как снижаться, так и расти. Поэтому следует дополнительно отлеживать долгосрочное удержание на основе метрики rolling retention.
# * Пик маректинговой активности пришелся на период с ноября 2017 года по январь 2018 года, а в сентябре, наоборот, произошло сокращение расходов по всем источникам. Наименее эффективными оказались маркетинговые кампании в августе, когда привлечение каждого пользователя стоило 10.8 у.е. Минимальный CAC был достигнут в мае и составил 7.4 у.е.
# * Источник №3 составляет почти половину совокупных расходов на маркетинг (равных 329131 у.е.) и доминировал в затратах на протяжении всего анализируемого периода, однако привлечение одного клиента через этот источник обходится более чем в 14 у.е. в то время как CAC 1, 9 и 10 источников не превышает 5 у.е. Когортный анализ ROMI также показал, что 3 источник не окупился ни для одной из когорт.
# * Когортный анализ показал, что с точки зрения накопленного за 6 месяцев LTV и ROMI сентябрьская когорта является наиболее ценной для бизнеса и окупилась на 4 месяц. Также на окупаемость вышла когорта июня - на 7 месяц после привлечения. В ноябре и окрябре были привлечены пользователи с наименьшим потенциалом LTV. В целом можно говорить о снижении эффективности рекламных кампаний с каждой новой когортой, однако в мае ситуация улучшилась.
#
# Таким образом, для повышения качества трафика и отдачи от маркетинговых вложений следует перераспределить маркетинговый бюджет в пользу более эффективных источников. Так, маркетологам стоит делать упор на быстро окупающиеся 1 и 2 источники, а 5 и 9 источники следует изучить и понять, что определяло успешность кампаний, поскольку для некорторых когорт они оказались эффективными, а для других не окупились на всем lifetime.
